# %%
from scripts.load_data import DataLoader
import sys
from pathlib import Path

ANALYZER_DIR = Path.cwd().parent

sys.path.insert(0, str(ANALYZER_DIR.resolve()))

# limpiar cache previo
if "scripts" in sys.modules:
    del sys.modules["scripts"]

# %%
loader = DataLoader().load_all()

# %%
loader.repositories.head()
# Out:
#                               repository_id        repository_name  \
# 0  9991dc2fdc4450f295d3673933856751e7c16bf9  ambari-presto-service
# 1  3e07d4c71e588445c016a7d056d7e15105f9524a              aws-proxy
# 2  72d2d74b93ff1171abcc53e0299a936c62fbe4e4                benchto
# 3  3c1836f3a69c98f75ea3c5cb3054a8e1afcca366                 charts
# 4  f3a839464298b1e2648da26706457d7aafd4e777                    cla
#
#    total_dependencies  total_dependency_vulnerabilities  \
# 0                   8                                 2
# 1                 840                                29
# 2                  76                                14
# 3                   8                                 0
# 4                   0                                 0
#
#    total_code_vulnerabilities                       analyzed_at  \
# 0                           0  2026-05-07T16:22:15.799748+00:00
# 1                           0  2026-05-07T16:22:15.799840+00:00
# ...

# %%
loader.repositories.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   repository_id                     46 non-null     str
#  1   repository_name                   46 non-null     str
#  2   total_dependencies                46 non-null     int64
#  3   total_dependency_vulnerabilities  46 non-null     int64
#  4   total_code_vulnerabilities        46 non-null     int64
#  5   analyzed_at                       46 non-null     str
#  6   analysis_status                   46 non-null     str
# dtypes: int64(3), str(4)
# memory usage: 6.9 KB

# %%
loader.dependencies.head()
# Out:
#                               dependency_id  \
# 0  56e7fac50f078364bb8d8b64985476565ddcb706
# 1  56e7fac50f078364bb8d8b64985476565ddcb706
# 2  fa57e5cc7dd7ea22fdf977709cda08b68276e66f
# 3  fa57e5cc7dd7ea22fdf977709cda08b68276e66f
# 4  9fc68aa4cec56911806dc42669f79e68f79538e3
#
#                               repository_id        repository_name  \
# 0  9991dc2fdc4450f295d3673933856751e7c16bf9  ambari-presto-service
# 1  9991dc2fdc4450f295d3673933856751e7c16bf9  ambari-presto-service
# 2  9991dc2fdc4450f295d3673933856751e7c16bf9  ambari-presto-service
# 3  9991dc2fdc4450f295d3673933856751e7c16bf9  ambari-presto-service
# 4  9991dc2fdc4450f295d3673933856751e7c16bf9  ambari-presto-service
#
#   artifact_name artifact_version artifact_type            package_url  \
# 0          mock            1.0.1        python    pkg:pypi/mock@1.0.1
# 1          mock            1.0.1        python    pkg:pypi/mock@1.0.1
# 2          nose            1.3.7        python    pkg:pypi/nose@1.3.7
# ...

# %%
loader.dependencies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7120 entries, 0 to 7119
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   dependency_id     7120 non-null   str
#  1   repository_id     7120 non-null   str
#  2   repository_name   7120 non-null   str
#  3   artifact_name     7120 non-null   str
#  4   artifact_version  7120 non-null   str
#  5   artifact_type     7120 non-null   str
#  6   package_url       7120 non-null   str
#  7   cpe               7120 non-null   object
#  8   licenses          7120 non-null   object
#  9   locations         7120 non-null   object
#  10  found_by          7120 non-null   str
#  11  metadata          7028 non-null   object
#  12  sbom_source       7120 non-null   str
#  13  analyzed_at       7120 non-null   str
# dtypes: object(4), str(10)
# memory usage: 2.3+ MB

# %%
loader.dependencies.isnull().sum()
# Out:
# dependency_id        0
# repository_id        0
# repository_name      0
# artifact_name        0
# artifact_version     0
# artifact_type        0
# package_url          0
# cpe                  0
# licenses             0
# locations            0
# found_by             0
# metadata            92
# sbom_source          0
# analyzed_at          0
# dtype: int64

# %%
loader.dependency_vulnerabilities.head()
# Out:
#                     vulnerability_record_id  \
# 0  b14d7c0940e22a35b43c46ab40c322db76044c8b
# 1  96b3f15b87a70d57873a7ad495a74171321f5ace
# 2  7afc9c4cc199b51456e5804929b3dade71de4507
# 3  55ec8300227489681df95a1aa4536cc5cbcbd3ff
# 4  a1f2117407e2c6ee6a617b1880c5bd2b079e36c9
#
#                               repository_id             repository  \
# 0  9991dc2fdc4450f295d3673933856751e7c16bf9  ambari-presto-service
# 1  9991dc2fdc4450f295d3673933856751e7c16bf9  ambari-presto-service
# 2  3e07d4c71e588445c016a7d056d7e15105f9524a              aws-proxy
# 3  3e07d4c71e588445c016a7d056d7e15105f9524a              aws-proxy
# 4  3e07d4c71e588445c016a7d056d7e15105f9524a              aws-proxy
#
#                               dependency_id      package_name package_version  \
# 0  c8478ce28dd44e584e619a5f594c3d62d71dfe86        virtualenv          12.0.7
# 1  c8478ce28dd44e584e619a5f594c3d62d71dfe86        virtualenv          12.0.7
# ...

# %%
loader.dependency_vulnerabilities.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 722 entries, 0 to 721
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vulnerability_record_id  722 non-null    str
#  1   repository_id            722 non-null    str
#  2   repository               722 non-null    str
#  3   dependency_id            722 non-null    str
#  4   package_name             722 non-null    str
#  5   package_version          722 non-null    str
#  6   package_type             722 non-null    str
#  7   language                 722 non-null    str
#  8   purl                     722 non-null    str
#  9   location                 722 non-null    str
#  10  vulnerability_id         722 non-null    str
#  11  related_cve              518 non-null    str
#  12  severity                 722 non-null    str
#  13  cvss_score               710 non-null    float64
#  14  epss                     660 non-null    float64
# ...

# %%
loader.dependency_vulnerabilities.isnull().sum()
# Out:
# vulnerability_record_id      0
# repository_id                0
# repository                   0
# dependency_id                0
# package_name                 0
# package_version              0
# package_type                 0
# language                     0
# purl                         0
# location                     0
# vulnerability_id             0
# related_cve                204
# severity                     0
# cvss_score                  12
# epss                        62
# risk                         0
# cwe                          0
# fix_state                    0
# fix_versions                 0
# description                  0
# data_source                  0
# namespace                    0
# tool                         0
# analyzed_at                  0
# dtype: int64

# %%
loader.code_vulnerabilities.head()
# Out:
#                                  finding_id  \
# 0  9c9ba22e313a210942fe744a63f949808f46c004
# 1  af850b84b02440e46b1e948a30698ae08ef0b9b8
# 2  b918c447dff5913baacdc04210bca45419a2336a
# 3  4f7094fa4ffa379bffff93b2caa48cfe1fee1591
# 4  6df6c760e5924059be76ad0a775437fd8195c974
#
#                               repository_id             rule_id severity  \
# 0  539489521a87dff7364bcf49dcb350dcbdebac92              js/xss  warning
# 1  539489521a87dff7364bcf49dcb350dcbdebac92              js/xss  warning
# 2  539489521a87dff7364bcf49dcb350dcbdebac92              js/xss  warning
# 3  539489521a87dff7364bcf49dcb350dcbdebac92              js/xss  warning
# 4  539489521a87dff7364bcf49dcb350dcbdebac92  js/xss-through-dom  warning
#
#                                                                     message  \
# 0       Cross-site scripting vulnerability due to [user-provided value](1).
# 1       Cross-site scripting vulnerability due to [user-provided value](1).
# ...

# %%
loader.code_vulnerabilities.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   finding_id     23 non-null     str
#  1   repository_id  23 non-null     str
#  2   rule_id        23 non-null     str
#  3   severity       23 non-null     str
#  4   message        23 non-null     str
#  5   file_path      23 non-null     str
#  6   start_line     23 non-null     int64
#  7   end_line       0 non-null      object
#  8   start_column   23 non-null     int64
#  9   end_column     23 non-null     int64
#  10  kind           23 non-null     str
#  11  tool           23 non-null     str
#  12  analyzed_at    23 non-null     str
# dtypes: int64(3), object(1), str(9)
# memory usage: 8.5+ KB

# %%
loader.code_vulnerabilities.isnull().sum()
# Out:
# finding_id        0
# repository_id     0
# rule_id           0
# severity          0
# message           0
# file_path         0
# start_line        0
# end_line         23
# start_column      0
# end_column        0
# kind              0
# tool              0
# analyzed_at       0
# dtype: int64
