# %%
from scripts.metrics import MetricsBuilder
from scripts.load_data import DataLoader
import sys
from pathlib import Path

import pandas as pd

ANALYZER_DIR = Path.cwd().parent

# prioridad al analyzer local
sys.path.insert(0, str(ANALYZER_DIR.resolve()))

# limpiar módulos cacheados
for module in list(sys.modules):
    if module == "scripts" or module.startswith("scripts."):
        del sys.modules[module]

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)
pd.set_option("display.max_colwidth", 200)

# imports DESPUÉS del sys.path

loader = DataLoader().load_all()

metrics = MetricsBuilder(loader)

# %%
repository_risk = (
    metrics.repository_risk()
)

repository_risk.head(30)
# Out:
# normalized_severity                                repository  critical_count  \
# 20                                             trino-packages              12
# 6                                              github-actions               3
# 12                                                trino-admin               6
# 11                                                      trino               1
# 3                                                   aws-proxy               0
# 10                                                     tempto               3
# 14                                              trino-gateway               0
# 4                                                     benchto               4
# 17                                          trino-hive-apache               5
# 0                    539489521a87dff7364bcf49dcb350dcbdebac92               0
# 19                                            trino-js-client               0
# 22                                                trino-rubix               3
# 5                                               docker-images               0
# 15                                            trino-go-client               0
# 18                                            trino-hive-jdbc               1
# 21                                             trino-query-ui               0
# 7                                               grafana-trino               1
# 9                                     presto-cassandra-server               1
# 13                                                trino-coral               0
# 23                                     trino-verifier-queries               0
# 16                                        trino-hadoop-apache               0
# 2                                       ambari-presto-service               0
# 25                                      trino-yugabyte-driver               0
# 24                                                 trino-yarn               0
# 8                                                orc-protobuf               0
# 26                                                   trino.io               0
# 1                    8d2730953f62a400e1feac6a6716a606d6bc2be8               0
#
# normalized_severity  high_count  low_count  medium_count  unknown_count  \
# 20                          142         68           138              0
# 6                            28          4            37              0
# 12                           24          2            18              0
# 11                           15          4            25              0
# 3                            11          3            15              0
# 10                            8          1            13              0
# 14                           12          1             9              0
# 4                             6          1             3              0
# 17                            5          1             2              0
# 0                             0          0            22              0
# 19                            5          1            11              0
# 22                            5          2             3              0
# 5                             7          1             6              0
# 15                            5          0             3              0
# 18                            2          1             3              0
# 21                            0          0             9              0
# 7                             2          0             0              0
# 9                             2          0             0              0
# 13                            2          1             1              0
# 23                            1          0             2              0
# 16                            2          1             0              0
# 2                             1          0             1              0
# 25                            0          1             2              0
# 24                            1          0             0              0
# 8                             1          0             0              0
# 26                            1          0             0              0
# 1                             0          0             1              0
#
# normalized_severity  total_vulnerabilities  risk_score
# 20                                     360         830
# 6                                       72         177
# 12                                      50         140
# 11                                      45         104
# 3                                       29          66
# 10                                      25          66
# 14                                      22          55
# 4                                       14          45
# 17                                      13          45
# 0                                       22          44
# 19                                      17          38
# 22                                      13          38
# 5                                       14          34
# 15                                       8          21
# 18                                       7          18
# 21                                       9          18
# 7                                        3          11
# 9                                        3          11
# 13                                       4           9
# 23                                       3           7
# 16                                       3           7
# 2                                        2           5
# 25                                       3           5
# 24                                       1           3
# 8                                        1           3
# 26                                       1           3
# 1                                        1           2

# %%
repository_risk.sort_values(
    by="risk_score",
    ascending=False,
).head(20)
# Out:
# normalized_severity                                repository  critical_count  \
# 20                                             trino-packages              12
# 6                                              github-actions               3
# 12                                                trino-admin               6
# 11                                                      trino               1
# 3                                                   aws-proxy               0
# 10                                                     tempto               3
# 14                                              trino-gateway               0
# 4                                                     benchto               4
# 17                                          trino-hive-apache               5
# 0                    539489521a87dff7364bcf49dcb350dcbdebac92               0
# 19                                            trino-js-client               0
# 22                                                trino-rubix               3
# 5                                               docker-images               0
# 15                                            trino-go-client               0
# 18                                            trino-hive-jdbc               1
# 21                                             trino-query-ui               0
# 7                                               grafana-trino               1
# 9                                     presto-cassandra-server               1
# 13                                                trino-coral               0
# 23                                     trino-verifier-queries               0
#
# normalized_severity  high_count  low_count  medium_count  unknown_count  \
# 20                          142         68           138              0
# 6                            28          4            37              0
# 12                           24          2            18              0
# 11                           15          4            25              0
# 3                            11          3            15              0
# 10                            8          1            13              0
# 14                           12          1             9              0
# 4                             6          1             3              0
# 17                            5          1             2              0
# 0                             0          0            22              0
# 19                            5          1            11              0
# 22                            5          2             3              0
# 5                             7          1             6              0
# 15                            5          0             3              0
# 18                            2          1             3              0
# 21                            0          0             9              0
# 7                             2          0             0              0
# 9                             2          0             0              0
# 13                            2          1             1              0
# 23                            1          0             2              0
#
# normalized_severity  total_vulnerabilities  risk_score
# 20                                     360         830
# 6                                       72         177
# 12                                      50         140
# 11                                      45         104
# 3                                       29          66
# 10                                      25          66
# 14                                      22          55
# 4                                       14          45
# 17                                      13          45
# 0                                       22          44
# 19                                      17          38
# 22                                      13          38
# 5                                       14          34
# 15                                       8          21
# 18                                       7          18
# 21                                       9          18
# 7                                        3          11
# 9                                        3          11
# 13                                       4           9
# 23                                       3           7
